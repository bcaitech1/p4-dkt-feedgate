# %% [markdown]
# ## 1. Data Load

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_theme(color_codes=True)
import missingno as msno
import time
from datetime import datetime
from tqdm import tqdm

# %%
# %%time
dtype = {
    'userID': 'int16',
    'answerCode': 'int8',
    'KnowledgeTag': 'int16'
}   

# 데이터 경로 맞춰주세요!
DATA_PATH = './input/data/train_dataset/train_data.csv'

df = pd.read_csv(DATA_PATH)
# df = df.sort_values(by=['userID', 'Timestamp']).reset_index(drop=True)
# Out:
# CPU times: user 2.71 s, sys: 232 ms, total: 2.94 s
# Wall time: 2.97 s

# %%
df
# Out:
#          userID assessmentItemID      testId  answerCode            Timestamp  \
# 0             0       A060001001  A060000001           1  2020-03-24 00:17:11
# 1             0       A060001002  A060000001           1  2020-03-24 00:17:14
# 2             0       A060001003  A060000001           1  2020-03-24 00:17:22
# 3             0       A060001004  A060000001           1  2020-03-24 00:17:29
# 4             0       A060001005  A060000001           1  2020-03-24 00:17:36
# ...         ...              ...         ...         ...                  ...
# 2266581    7441       A030071005  A030000071           0  2020-06-05 06:50:21
# 2266582    7441       A040165001  A040000165           1  2020-08-21 01:06:39
# 2266583    7441       A040165002  A040000165           1  2020-08-21 01:06:50
# 2266584    7441       A040165003  A040000165           1  2020-08-21 01:07:36
# 2266585    7441       A040165004  A040000165           1  2020-08-21 01:08:49
#
#          KnowledgeTag
# 0                7224
# 1                7225
# 2                7225
# 3                7225
# 4                7225
# ...               ...
# 2266581           438
# 2266582          8836
# 2266583          8836
# 2266584          8836
# 2266585          8836
#
# [2266586 rows x 6 columns]

# %% [markdown]
# ### Time convert

# %%
def convert_time(s):
    timestamp = time.mktime(datetime.strptime(s, '%Y-%m-%d %H:%M:%S').timetuple())
    return int(timestamp)

df['Timestamp'] = df['Timestamp'].apply(convert_time)

# %%
# dataframe 사용자별, 시간순으로 정렬
df = df.sort_values(by=['userID','Timestamp'], axis=0)

# %% [markdown]
# ## 2. 사용자별 누적 문제 풀이 갯수 & 정답률

# %%
# 사용자별 누적 정답 갯수
user_cumsum = df.loc[:, ['userID', 'answerCode']].groupby('userID').transform(lambda x: x.cumsum().shift(1))
# 사용자별 누적갯수
user_cumcount = df.loc[:, ['userID', 'answerCode']].groupby('userID').agg({'answerCode': 'cumcount'})
# 사용자별 누적 정답률
user_ans = user_cumsum / user_cumcount

df['user_ans'] = user_ans
df['user_cnt'] = user_cumcount

# %%
df
# Out:
#         userID assessmentItemID      testId  answerCode            Timestamp  \
# 0            3       A050023001  A050000023           1  2020-01-09 10:56:31
# 1            3       A050023002  A050000023           1  2020-01-09 10:56:57
# 2            3       A050023003  A050000023           0  2020-01-09 10:58:31
# 3            3       A050023004  A050000023           0  2020-01-09 10:58:36
# 4            3       A050023006  A050000023           0  2020-01-09 10:58:43
# ...        ...              ...         ...         ...                  ...
# 260109    7439       A040130001  A040000130           0  2020-10-14 23:07:23
# 260110    7439       A040130002  A040000130           1  2020-10-14 23:07:41
# 260111    7439       A040130003  A040000130           1  2020-10-14 23:08:02
# 260112    7439       A040130004  A040000130           1  2020-10-14 23:09:31
# 260113    7439       A040130005  A040000130          -1  2020-10-14 23:10:03
#
#         KnowledgeTag
# 0               2626
# 1               2626
# 2               2625
# 3               2625
# 4               2623
# ...              ...
# 260109          8832
# 260110          8832
# 260111          8244
# 260112          8244
# 260113          8832
#
# [260114 rows x 6 columns]

# %% [markdown]
# ## 3. Elapsed time

# %%
df['elapsed_time'] = df.loc[:, ['userID', 'Timestamp']].groupby('userID').diff().shift(-1)

# %%
df
# Out:
#         userID assessmentItemID      testId  answerCode   Timestamp  \
# 0            3       A050023001  A050000023           1  1578567391
# 1            3       A050023002  A050000023           1  1578567417
# 2            3       A050023003  A050000023           0  1578567511
# 3            3       A050023004  A050000023           0  1578567516
# 4            3       A050023006  A050000023           0  1578567523
# ...        ...              ...         ...         ...         ...
# 260109    7439       A040130001  A040000130           0  1602716843
# 260110    7439       A040130002  A040000130           1  1602716861
# 260111    7439       A040130003  A040000130           1  1602716882
# 260112    7439       A040130004  A040000130           1  1602716971
# 260113    7439       A040130005  A040000130          -1  1602717003
#
#         KnowledgeTag  user_ans  user_cnt  elapsed_time
# 0               2626       NaN         0          26.0
# 1               2626  1.000000         1          94.0
# 2               2625  1.000000         2           5.0
# 3               2625  0.666667         3           7.0
# 4               2623  0.500000         4           3.0
# ...              ...       ...       ...           ...
# 260109          8832  0.727273        11          18.0
# 260110          8832  0.666667        12          21.0
# 260111          8244  0.692308        13          89.0
# 260112          8244  0.714286        14          32.0
# 260113          8832  0.733333        15           NaN
#
# [260114 rows x 9 columns]

# %% [markdown]
# ## 4. assignmentID -> Category, Number

# %%
df['category'] = df['assessmentItemID'].apply(lambda x: x[2])

# %%
df.head()
# Out:
#    userID assessmentItemID      testId  answerCode   Timestamp  KnowledgeTag  \
# 0       3       A050023001  A050000023           1  1578567391          2626
# 1       3       A050023002  A050000023           1  1578567417          2626
# 2       3       A050023003  A050000023           0  1578567511          2625
# 3       3       A050023004  A050000023           0  1578567516          2625
# 4       3       A050023006  A050000023           0  1578567523          2623
#
#    user_ans  user_cnt  elapsed_time category
# 0       NaN         0          26.0        5
# 1  1.000000         1          94.0        5
# 2  1.000000         2           5.0        5
# 3  0.666667         3           7.0        5
# 4  0.500000         4           3.0        5

# %% [markdown]
# ### Category별 누적 정답률

# %%
# 사용자별 누적 정답 갯수
cate_cumsum = df.loc[:, ['userID', 'answerCode','category']].groupby(['userID','category']).transform(lambda x: x.cumsum().shift(1))
# 사용자별 누적갯수
cate_cumcount = df.loc[:, ['userID', 'answerCode','category']].groupby(['userID','category']).agg({'answerCode': 'cumcount'})
# 사용자별 누적 정답률
cate_ans = cate_cumsum / cate_cumcount

df['cate_ans'] = cate_ans
df['cate_cnt'] = cate_cumcount

# %%
df.head(10)
# Out:
#    userID assessmentItemID      testId  answerCode   Timestamp  KnowledgeTag  \
# 0       3       A050023001  A050000023           1  1578567391          2626
# 1       3       A050023002  A050000023           1  1578567417          2626
# 2       3       A050023003  A050000023           0  1578567511          2625
# 3       3       A050023004  A050000023           0  1578567516          2625
# 4       3       A050023006  A050000023           0  1578567523          2623
# 5       3       A050023007  A050000023           0  1578567526          2623
# 6       3       A050023005  A050000023           0  1578567551           192
# 7       3       A050027001  A050000027           0  1578920215          3691
# 8       3       A050027002  A050000027           0  1578920366          3691
# 9       3       A050027003  A050000027           0  1578920429          3682
#
#    user_ans  user_cnt  elapsed_time category  cate_ans  cate_cnt
# 0       NaN         0          26.0        5       NaN         0
# 1  1.000000         1          94.0        5  1.000000         1
# 2  1.000000         2           5.0        5  1.000000         2
# 3  0.666667         3           7.0        5  0.666667         3
# 4  0.500000         4           3.0        5  0.500000         4
# 5  0.400000         5          25.0        5  0.400000         5
# 6  0.333333         6      352664.0        5  0.333333         6
# 7  0.285714         7         151.0        5  0.285714         7
# 8  0.250000         8          63.0        5  0.250000         8
# 9  0.222222         9          17.0        5  0.222222         9

# %%
df['number'] = df['assessmentItemID'].apply(lambda x: x[0]+x[-6:])

# %% [markdown]
# ## 5. testID별 누적 정답률

# %%
# 사용자별 누적 정답 갯수
test_cumsum = df.loc[:, ['userID', 'answerCode','testId']].groupby(['userID','testId']).transform(lambda x: x.cumsum().shift(1))

# %%
# 사용자별 누적갯수
test_cumcount = df.loc[:, ['userID', 'answerCode','testId']].groupby(['userID','testId']).agg({'answerCode': 'cumcount'})

# %%
# 사용자별 누적 정답률
test_ans = test_cumsum / test_cumcount

df['test_ans'] = test_ans
df['test_cnt'] = test_cumcount
df['test_cumsum'] = test_cumsum

# %%
df.head(20)
# Out:
#     userID assessmentItemID      testId  answerCode   Timestamp  KnowledgeTag  \
# 0        3       A050023001  A050000023           1  1578567391          2626
# 1        3       A050023002  A050000023           1  1578567417          2626
# 2        3       A050023003  A050000023           0  1578567511          2625
# 3        3       A050023004  A050000023           0  1578567516          2625
# 4        3       A050023006  A050000023           0  1578567523          2623
# 5        3       A050023007  A050000023           0  1578567526          2623
# 6        3       A050023005  A050000023           0  1578567551           192
# 7        3       A050027001  A050000027           0  1578920215          3691
# 8        3       A050027002  A050000027           0  1578920366          3691
# 9        3       A050027003  A050000027           0  1578920429          3682
# 10       3       A050027004  A050000027           0  1578920446          3691
# 11       3       A050027006  A050000027           0  1578920778          3691
# 12       3       A050027007  A050000027           0  1578920797          3682
# 13       3       A050027005  A050000027           0  1578920835           202
# 14       3       A050037001  A050000037           1  1579181767          3703
# 15       3       A050037002  A050000037           0  1579182138          3703
# 16       3       A050037003  A050000037           0  1579182455          3703
# 17       3       A050037004  A050000037           1  1579183129          3703
# 18       3       A050037005  A050000037           0  1579183147          3703
# 19       3       A050037006  A050000037           0  1579183161          3703
#
#     user_ans  user_cnt  elapsed_time category  cate_ans  cate_cnt   number  \
# 0        NaN         0          26.0        5       NaN         0  A023001
# 1   1.000000         1          94.0        5  1.000000         1  A023002
# 2   1.000000         2           5.0        5  1.000000         2  A023003
# 3   0.666667         3           7.0        5  0.666667         3  A023004
# 4   0.500000         4           3.0        5  0.500000         4  A023006
# 5   0.400000         5          25.0        5  0.400000         5  A023007
# 6   0.333333         6      352664.0        5  0.333333         6  A023005
# 7   0.285714         7         151.0        5  0.285714         7  A027001
# 8   0.250000         8          63.0        5  0.250000         8  A027002
# 9   0.222222         9          17.0        5  0.222222         9  A027003
# 10  0.200000        10         332.0        5  0.200000        10  A027004
# 11  0.181818        11          19.0        5  0.181818        11  A027006
# 12  0.166667        12          38.0        5  0.166667        12  A027007
# 13  0.153846        13      260932.0        5  0.153846        13  A027005
# 14  0.142857        14         371.0        5  0.142857        14  A037001
# 15  0.200000        15         317.0        5  0.200000        15  A037002
# 16  0.187500        16         674.0        5  0.187500        16  A037003
# 17  0.176471        17          18.0        5  0.176471        17  A037004
# 18  0.222222        18          14.0        5  0.222222        18  A037005
# 19  0.210526        19         163.0        5  0.210526        19  A037006
#
#     test_ans  test_cnt  test_cumsum
# 0        NaN         0          NaN
# 1   1.000000         1          1.0
# 2   1.000000         2          2.0
# 3   0.666667         3          2.0
# 4   0.500000         4          2.0
# 5   0.400000         5          2.0
# 6   0.333333         6          2.0
# 7        NaN         0          NaN
# 8   0.000000         1          0.0
# 9   0.000000         2          0.0
# 10  0.000000         3          0.0
# 11  0.000000         4          0.0
# 12  0.000000         5          0.0
# 13  0.000000         6          0.0
# 14       NaN         0          NaN
# 15  1.000000         1          1.0
# 16  0.500000         2          1.0
# 17  0.333333         3          1.0
# 18  0.500000         4          2.0
# 19  0.400000         5          2.0

# %% [markdown]
# ## 6. KnowledgeTag별 누적 정답률

# %%
# 사용자별 누적 정답 갯수
tag_cumsum = df.loc[:, ['userID', 'answerCode','KnowledgeTag']].groupby(['userID','KnowledgeTag']).transform(lambda x: x.cumsum().shift(1))
# 사용자별 누적갯수
tag_cumcount = df.loc[:, ['userID', 'answerCode','KnowledgeTag']].groupby(['userID','KnowledgeTag']).agg({'answerCode': 'cumcount'})
# 사용자별 누적 정답률
tag_ans = tag_cumsum / tag_cumcount

df['tag_ans'] = tag_ans
df['tag_cnt'] = tag_cumcount

# %%
df.head(20)
# Out:
#     userID assessmentItemID      testId  answerCode   Timestamp  KnowledgeTag  \
# 0        3       A050023001  A050000023           1  1578567391          2626
# 1        3       A050023002  A050000023           1  1578567417          2626
# 2        3       A050023003  A050000023           0  1578567511          2625
# 3        3       A050023004  A050000023           0  1578567516          2625
# 4        3       A050023006  A050000023           0  1578567523          2623
# 5        3       A050023007  A050000023           0  1578567526          2623
# 6        3       A050023005  A050000023           0  1578567551           192
# 7        3       A050027001  A050000027           0  1578920215          3691
# 8        3       A050027002  A050000027           0  1578920366          3691
# 9        3       A050027003  A050000027           0  1578920429          3682
# 10       3       A050027004  A050000027           0  1578920446          3691
# 11       3       A050027006  A050000027           0  1578920778          3691
# 12       3       A050027007  A050000027           0  1578920797          3682
# 13       3       A050027005  A050000027           0  1578920835           202
# 14       3       A050037001  A050000037           1  1579181767          3703
# 15       3       A050037002  A050000037           0  1579182138          3703
# 16       3       A050037003  A050000037           0  1579182455          3703
# 17       3       A050037004  A050000037           1  1579183129          3703
# 18       3       A050037005  A050000037           0  1579183147          3703
# 19       3       A050037006  A050000037           0  1579183161          3703
#
#     user_ans  user_cnt  elapsed_time category  cate_ans  cate_cnt   number  \
# 0        NaN         0          26.0        5       NaN         0  A023001
# 1   1.000000         1          94.0        5  1.000000         1  A023002
# 2   1.000000         2           5.0        5  1.000000         2  A023003
# 3   0.666667         3           7.0        5  0.666667         3  A023004
# 4   0.500000         4           3.0        5  0.500000         4  A023006
# 5   0.400000         5          25.0        5  0.400000         5  A023007
# 6   0.333333         6      352664.0        5  0.333333         6  A023005
# 7   0.285714         7         151.0        5  0.285714         7  A027001
# 8   0.250000         8          63.0        5  0.250000         8  A027002
# 9   0.222222         9          17.0        5  0.222222         9  A027003
# 10  0.200000        10         332.0        5  0.200000        10  A027004
# 11  0.181818        11          19.0        5  0.181818        11  A027006
# 12  0.166667        12          38.0        5  0.166667        12  A027007
# 13  0.153846        13      260932.0        5  0.153846        13  A027005
# 14  0.142857        14         371.0        5  0.142857        14  A037001
# 15  0.200000        15         317.0        5  0.200000        15  A037002
# 16  0.187500        16         674.0        5  0.187500        16  A037003
# 17  0.176471        17          18.0        5  0.176471        17  A037004
# 18  0.222222        18          14.0        5  0.222222        18  A037005
# 19  0.210526        19         163.0        5  0.210526        19  A037006
#
#     test_ans  test_cnt  test_cumsum   tag_ans  tag_cnt
# 0        NaN         0          NaN       NaN        0
# 1   1.000000         1          1.0  1.000000        1
# 2   1.000000         2          2.0       NaN        0
# 3   0.666667         3          2.0  0.000000        1
# 4   0.500000         4          2.0       NaN        0
# 5   0.400000         5          2.0  0.000000        1
# 6   0.333333         6          2.0       NaN        0
# 7        NaN         0          NaN       NaN        0
# 8   0.000000         1          0.0  0.000000        1
# 9   0.000000         2          0.0       NaN        0
# 10  0.000000         3          0.0  0.000000        2
# 11  0.000000         4          0.0  0.000000        3
# 12  0.000000         5          0.0  0.000000        1
# 13  0.000000         6          0.0       NaN        0
# 14       NaN         0          NaN       NaN        0
# 15  1.000000         1          1.0  1.000000        1
# 16  0.500000         2          1.0  0.500000        2
# 17  0.333333         3          1.0  0.333333        3
# 18  0.500000         4          2.0  0.500000        4
# 19  0.400000         5          2.0  0.400000        5

# %% [markdown]
# ### KnowledgeTag별 평균 정답률

# %%
tag_group = df.loc[:, ['userID', 'answerCode','KnowledgeTag']].groupby('KnowledgeTag').agg({'answerCode': 'mean'})

# %%
tag_group.loc[23]['answerCode']
# Out:
# 0.67

# %%
def tag_mean(x):
    return tag_group.loc[x]['answerCode']

# %%
df['tag_mean'] = df['KnowledgeTag'].apply(tag_mean)

# %%
df.columns
# Out:
# Index(['userID', 'assessmentItemID', 'testId', 'answerCode', 'Timestamp',
#        'KnowledgeTag', 'user_ans', 'user_cnt', 'elapsed_time', 'category',
#        'cate_ans', 'cate_cnt', 'number', 'test_ans', 'test_cnt', 'test_cumsum',
#        'tag_ans', 'tag_cnt', 'tag_mean'],
#       dtype='object')

# %%
DATA_PATH_3 = './input/data/train_dataset/tuning_data.csv'

data = pd.read_csv(DATA_PATH_3)

# %%
data = data[data.datasetType==0]

# %%
data
# Out:
#          userID  testCategory      testID     assmtID  assmtCorrectRate  \
# 0             0            60  A060000001  A060001001          0.984000
# 1             0            60  A060000001  A060001002          0.968000
# 2             0            60  A060000001  A060001003          0.916000
# 3             0            60  A060000001  A060001004          0.972000
# 4             0            60  A060000001  A060001005          0.948000
# ...         ...           ...         ...         ...               ...
# 2266581    7441            30  A030000071  A030071005          0.446667
# 2266582    7441            40  A040000165  A040165001          0.643333
# 2266583    7441            40  A040000165  A040165002          0.640000
# 2266584    7441            40  A040000165  A040165003          0.786667
# 2266585    7441            40  A040000165  A040165004          0.545151
#
#          assmtETMedian  cumInteraction  cumCorrectRate  retry  \
# 0                    6               0        0.500000      0
# 1                   14               1        1.000000      0
# 2                   10               2        1.000000      0
# 3                   11               3        1.000000      0
# 4                   21               4        1.000000      0
# ...                ...             ...             ...    ...
# 2266581             46               4        0.292486      0
# 2266582             17               5        0.253253      0
# 2266583             14               6        0.374161      0
# 2266584             78               7        0.460983      0
# 2266585             68               8        0.539506      0
#
#                    timestamp    unixTime  relTime2Last  elapsedTime  \
# 0        2020-03-24 00:17:11  1585009031     -23685788            3
# 1        2020-03-24 00:17:14  1585009034     -23685785            8
# 2        2020-03-24 00:17:22  1585009042     -23685777            7
# 3        2020-03-24 00:17:29  1585009049     -23685770            7
# 4        2020-03-24 00:17:36  1585009056     -23685763           11
# ...                      ...         ...           ...          ...
# 2266581  2020-06-05 06:50:21  1591339821      -6632308           89
# 2266582  2020-08-21 01:06:39  1597971999          -130           11
# 2266583  2020-08-21 01:06:50  1597972010          -119           46
# 2266584  2020-08-21 01:07:36  1597972056           -73           73
# 2266585  2020-08-21 01:08:49  1597972129             0           67
#
#          _elapsedTime  relElapsedTime  knowledgeTag  cumTag  \
# 0                   3        0.500000          7224       0
# 1                   8        0.571429          7225       0
# 2                   7        0.700000          7225       1
# 3                   7        0.636364          7225       2
# 4                  11        0.523810          7225       3
# ...               ...             ...           ...     ...
# 2266581            -2        1.934783           438       4
# 2266582            11        0.647059          8836       0
# 2266583            46        3.285714          8836       1
# 2266584            73        0.935897          8836       2
# 2266585            -1        0.985294          8836       3
#
#          cumTagCorrectRate  answerCode  datasetType
# 0                 0.500000           1            0
# 1                 0.500000           1            0
# 2                 1.000000           1            0
# 3                 1.000000           1            0
# 4                 1.000000           1            0
# ...                    ...         ...          ...
# 2266581           0.292486           0            0
# 2266582           0.500000           1            0
# 2266583           1.000000           1            0
# 2266584           1.000000           1            0
# 2266585           1.000000           1            0
#
# [2266586 rows x 20 columns]

# %%
DATA_PATH_4 = './input/data/train_dataset/tuning_train_data.csv'

data2 = pd.read_csv(DATA_PATH_4)

# %%
data2
# Out:
#          userID assessmentItemID      testId  answerCode   Timestamp  \
# 0             0       A060001001  A060000001           1  1585009031
# 1             0       A060001002  A060000001           1  1585009034
# 2             0       A060001003  A060000001           1  1585009042
# 3             0       A060001004  A060000001           1  1585009049
# 4             0       A060001005  A060000001           1  1585009056
# ...         ...              ...         ...         ...         ...
# 2266581    7441       A030071005  A030000071           0  1591339821
# 2266582    7441       A040165001  A040000165           1  1597971999
# 2266583    7441       A040165002  A040000165           1  1597972010
# 2266584    7441       A040165003  A040000165           1  1597972056
# 2266585    7441       A040165004  A040000165           1  1597972129
#
#          KnowledgeTag  user_ans  user_cnt  elapsed_time  category  cate_ans  \
# 0                7224       NaN         0           3.0         6       NaN
# 1                7225  1.000000         1           8.0         6      1.00
# 2                7225  1.000000         2           7.0         6      1.00
# 3                7225  1.000000         3           7.0         6      1.00
# 4                7225  1.000000         4          11.0         6      1.00
# ...               ...       ...       ...           ...       ...       ...
# 2266581           438  0.250000         4     6632178.0         3      0.25
# 2266582          8836  0.200000         5          11.0         4       NaN
# 2266583          8836  0.333333         6          46.0         4      1.00
# 2266584          8836  0.428571         7          73.0         4      1.00
# 2266585          8836  0.500000         8           NaN         4      1.00
#
#          cate_cnt   number  test_ans  test_cnt  test_cumsum  tag_ans  tag_cnt  \
# 0               0  A001001       NaN         0          NaN      NaN        0
# 1               1  A001002      1.00         1          1.0      NaN        0
# 2               2  A001003      1.00         2          2.0     1.00        1
# 3               3  A001004      1.00         3          3.0     1.00        2
# 4               4  A001005      1.00         4          4.0     1.00        3
# ...           ...      ...       ...       ...          ...      ...      ...
# 2266581         4  A071005      0.25         4          1.0     0.25        4
# 2266582         0  A165001       NaN         0          NaN      NaN        0
# 2266583         1  A165002      1.00         1          1.0     1.00        1
# 2266584         2  A165003      1.00         2          2.0     1.00        2
# 2266585         3  A165004      1.00         3          3.0     1.00        3
#
#          tag_mean
# 0        0.955022
# 1        0.913187
# 2        0.913187
# 3        0.913187
# 4        0.913187
# ...           ...
# 2266581  0.689706
# 2266582  0.697874
# 2266583  0.697874
# 2266584  0.697874
# 2266585  0.697874
#
# [2266586 rows x 19 columns]

# %%
data2['relElapsedTime'] = data['relElapsedTime']

# %%
data2.columns
# Out:
# Index(['userID', 'assessmentItemID', 'testId', 'answerCode', 'Timestamp',
#        'KnowledgeTag', 'user_ans', 'user_cnt', 'elapsed_time', 'category',
#        'cate_ans', 'cate_cnt', 'number', 'test_ans', 'test_cnt', 'test_cumsum',
#        'tag_ans', 'tag_cnt', 'tag_mean', 'relElapsedTime'],
#       dtype='object')

# %%
data2
# Out:
#          userID assessmentItemID      testId  answerCode   Timestamp  \
# 0             0       A060001001  A060000001           1  1585009031
# 1             0       A060001002  A060000001           1  1585009034
# 2             0       A060001003  A060000001           1  1585009042
# 3             0       A060001004  A060000001           1  1585009049
# 4             0       A060001005  A060000001           1  1585009056
# ...         ...              ...         ...         ...         ...
# 2266581    7441       A030071005  A030000071           0  1591339821
# 2266582    7441       A040165001  A040000165           1  1597971999
# 2266583    7441       A040165002  A040000165           1  1597972010
# 2266584    7441       A040165003  A040000165           1  1597972056
# 2266585    7441       A040165004  A040000165           1  1597972129
#
#          KnowledgeTag  user_ans  user_cnt  elapsed_time  category  cate_ans  \
# 0                7224       NaN         0           3.0         6       NaN
# 1                7225  1.000000         1           8.0         6      1.00
# 2                7225  1.000000         2           7.0         6      1.00
# 3                7225  1.000000         3           7.0         6      1.00
# 4                7225  1.000000         4          11.0         6      1.00
# ...               ...       ...       ...           ...       ...       ...
# 2266581           438  0.250000         4     6632178.0         3      0.25
# 2266582          8836  0.200000         5          11.0         4       NaN
# 2266583          8836  0.333333         6          46.0         4      1.00
# 2266584          8836  0.428571         7          73.0         4      1.00
# 2266585          8836  0.500000         8           NaN         4      1.00
#
#          cate_cnt   number  test_ans  test_cnt  test_cumsum  tag_ans  tag_cnt  \
# 0               0  A001001       NaN         0          NaN      NaN        0
# 1               1  A001002      1.00         1          1.0      NaN        0
# 2               2  A001003      1.00         2          2.0     1.00        1
# 3               3  A001004      1.00         3          3.0     1.00        2
# 4               4  A001005      1.00         4          4.0     1.00        3
# ...           ...      ...       ...       ...          ...      ...      ...
# 2266581         4  A071005      0.25         4          1.0     0.25        4
# 2266582         0  A165001       NaN         0          NaN      NaN        0
# 2266583         1  A165002      1.00         1          1.0     1.00        1
# 2266584         2  A165003      1.00         2          2.0     1.00        2
# 2266585         3  A165004      1.00         3          3.0     1.00        3
#
#          tag_mean  relElapsedTime
# 0        0.955022        0.500000
# 1        0.913187        0.571429
# 2        0.913187        0.700000
# 3        0.913187        0.636364
# 4        0.913187        0.523810
# ...           ...             ...
# 2266581  0.689706        1.934783
# 2266582  0.697874        0.647059
# 2266583  0.697874        3.285714
# 2266584  0.697874        0.935897
# 2266585  0.697874        0.985294
#
# [2266586 rows x 20 columns]

# %%
data2.to_csv('./input/data/train_dataset/tuning_data2.csv',index=False,mode='w')
